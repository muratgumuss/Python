# %%
import math
math.sqrt(9)
# Out:
# 3.0

# %%
from math import sqrt,pi,pow
sqrt(9)
pi
pow(2,3)
math.cos(0)
# Out:
# 1.0

# %%
import numpy as np
np.sqrt(9)
# Out:
# np.float64(3.0)

# %%
from math import *
cos(0)
# Out:
# 1.0

# %%
import os
print(os.getcwd())
# Out:
# c:\dev\Python\PythonBasics

# %%
from package.maths import addition

result = addition(2, 3)
print(result)  # Çıktı: 5
# Out:
# 5

# %%
from package.subpackages import mult
result = mult.multiply(2, 3)
print(result)  # Çıktı: 6
# Out:
# 6

# %%
import package
print(dir(package))  # Burada 'addition' görünmeli
# Out:
# ['__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', 'maths']

# %%
import random
random.randint(1, 100)
random.choice([1, 2, 3, 4, 5])
# Out:
# 4

# %%
import os
print(os.getcwd())
os.listdir()
# Out:
# c:\dev\Python\PythonBasics
# ['FunctionTest.ipynb',
#  'import.ipynb',
#  'package',
#  'requirements.txt',
#  'sample.txt',
#  'test.ipynb',
#  'test.py']

# %%
import shutil
shutil.copy('example.txt', 'example2.txt')
shutil.move('example2.txt', 'example3.txt')

# %%
import json
data = {'name': 'John', 'age': 30}
with open('data.json', 'w') as f:
    json.dump(data, f)

print(type(data))  # Çıktı: {'name': 'John', 'age': 30}
parsed_data = json.loads('{"name": "John", "age": 30}')
print(parsed_data)  # Çıktı: {'name': 'John', 'age': 30}
# Out:
# <class 'dict'>
# {'name': 'John', 'age': 30}

# %%
import csv
with open('data.csv', 'w') as f:
    writer = csv.writer(f)
    writer.writerow(['name', 'age'])
    writer.writerow(['John', 30])
    writer.writerow(['Doe', 25])

with open('data.csv', 'r') as f:
    reader = csv.reader(f)

# %%
from datetime import datetime, timedelta
print(datetime.now())
print(datetime.now().strftime('%d-%m-%Y %H:%M:%S'))
print(datetime.now() + timedelta(days=3))

yesterday = datetime.now() - timedelta(days=1)
print(yesterday)
# Out:
# 2025-03-25 15:03:20.407285
# 25-03-2025 15:03:20
# 2025-03-28 15:03:20.407285
# 2025-03-24 15:03:20.407285

# %%
import time
print(time.time())
print(time.localtime())
print(time.strftime('%d-%m-%Y %H:%M:%S', time.localtime()))
time.sleep(2)
print('Hello, World!')
# Out:
# 1742904297.0424967
# time.struct_time(tm_year=2025, tm_mon=3, tm_mday=25, tm_hour=15, tm_min=4, tm_sec=57, tm_wday=1, tm_yday=84, tm_isdst=0)
# 25-03-2025 15:04:57
# Hello, World!

# %%
## Regular Expressions
import re
pattern = '^a...s$'
test_string = 'abyss'
result = re.match(pattern, test_string)
if result:
    print('Eşleşme bulundu.')
else:
    print('Eşleşme bulunamadı.')
# Out:
# Eşleşme bulundu.

# %%
## read a whole file
with open('sample.txt', 'r') as f:
    print(f.read())
# Out:
# Complete Guide to Building, Deploying, and Optimizing Generative AI with Langchain and Huggingface
# Complete

# %%
## read a file line by line
with open('sample.txt', 'r') as f:
    for line in f:
        print(line.strip())
# Out:
# Hello, World!
# Hello, Python!
# Hello, World!
# Hello, Python!
# Murat
# first line
# second line
# third line

# %%
## write to a file  
with open('sample.txt', 'w') as f:
    f.write('Hello, World!\n')
    f.write('Hello, Python!')

# %%
## write to a file without overwriting
with open('sample.txt', 'a') as f:
    f.write('\nHello, World!\n')
    f.write('Hello, Python!\n')
    f.write('Murat\n')

# %%
lines = ['first line\n', 'second line\n', 'third line\n']
with open('sample.txt', 'a') as f:
    f.writelines(lines)

# %%
## writing and then reading a file
with open('sample.txt', 'w+') as f:
    f.write('Hello, World!\n')
    f.write('Hello, Python!')
    f.seek(0)
    print(f.read())
# Out:
# Hello, World!
# Hello, Python!

# %%
## exception handling
try:
    print(1 / 0)
except ZeroDivisionError:
    print('Bir hata oluştu.')
finally:
    print('Bu her zaman çalışır.')
    
b = 2
try:
    a = b
except NameError as ex:
    print(ex)
except Exception as ex:
    print(ex)
# Out:
# Bir hata oluştu.
# Bu her zaman çalışır.
# name 'b' is not defined

# %%
## try except else block
try:
    print(1)
except ZeroDivisionError:
    print(2)
else:
    print(3)
finally:
    print(4)
# Out:
# 1
# 3
# 4

# %%
## file handling with exception handling
try:
    with open('sample.txt', 'r') as f:
        print(f.read())
except FileNotFoundError as ex:
    print(ex)
except Exception as ex:
    print(ex)
finally:
    print('Dosya okuma işlemi bitti.')
# Out:
# Hello, World!
# Hello, Python!
# Dosya okuma işlemi bitti.
