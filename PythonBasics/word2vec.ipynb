# %%
import gensim
from gensim.models import Word2Vec,KeyedVectors
import gensim.downloader as api

# %%
wv = api.load("word2vec-google-news-300")
# Out:
# [==================================================] 100.0% 1662.8/1662.8MB downloaded

# %%
vec_king = wv['king']
vec_king.shape
wv.most_similar('Turkey')
wv.similarity('Turkey', 'Indonesia')
wv.similarity('Turkey', 'Turkey')

vec = wv['Turkey'] + wv['Indonesia'] - wv['footballer']
wv.most_similar(positive=[vec])
# Out:
# [('Indonesia', 0.7071917057037354),
#  ('Turkey', 0.6851043105125427),
#  ('Malaysia', 0.5392076969146729),
#  ('Southeast_Asia', 0.5294399857521057),
#  ('Indonesian', 0.5127121806144714),
#  ('Morocco', 0.5100691914558411),
#  ('Thailand', 0.5074493885040283),
#  ('Saudi_Arabia', 0.4934101402759552),
#  ('Turkish', 0.46902161836624146),
#  ('Philippines', 0.46768438816070557)]
