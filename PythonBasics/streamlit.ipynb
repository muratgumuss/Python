# %%
import streamlit as st
import pandas as pd
import numpy as np

st.title("Streamlit Example App")
st.write("This is a simple example of a Streamlit app.")
# Out:
# 2025-04-08 17:15:07.379 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-08 17:15:07.811
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run c:\dev\Python\venv\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2025-04-08 17:15:07.812 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-08 17:15:07.813 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-08 17:15:07.814 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-08 17:15:07.814 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-08 17:15:07.815 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
