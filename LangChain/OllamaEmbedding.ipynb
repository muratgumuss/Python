# %%
from langchain_community.embeddings import OllamaEmbeddings

embeddings = OllamaEmbeddings(model="gemma:2b")
embeddings
# Out:
# C:\Users\murat\AppData\Local\Temp\ipykernel_19464\2286341005.py:3: LangChainDeprecationWarning: The class `OllamaEmbeddings` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the :class:`~langchain-ollama package and should be used instead. To use it run `pip install -U :class:`~langchain-ollama` and import as `from :class:`~langchain_ollama import OllamaEmbeddings``.
#   embeddings = OllamaEmbeddings(model="gemma:2b")
# OllamaEmbeddings(base_url='http://localhost:11434', model='gemma:2b', embed_instruction='passage: ', query_instruction='query: ', mirostat=None, mirostat_eta=None, mirostat_tau=None, num_ctx=None, num_gpu=None, num_thread=None, repeat_last_n=None, repeat_penalty=None, temperature=None, stop=None, tfs_z=None, top_k=None, top_p=None, show_progress=False, headers=None, model_kwargs=None)

# %% [markdown]
# ```markdown
# 1. Ollama Embedding Modelini Oluşturma
# Amaç: Ollama ile çalışan bir embedding (vektörleştirme) modeli başlatmak.
# Kütüphane: OllamaEmbeddings — Metinleri vektörlere dönüştürür. (Farklı paketlerden iki örnek gösterilmiş.)
# ```

# %%
from langchain_ollama import OllamaEmbeddings
embeddings = OllamaEmbeddings(model="gemma:2b")
embeddings
# Out:
# OllamaEmbeddings(model='gemma:2b', base_url=None, client_kwargs={}, async_client_kwargs={}, sync_client_kwargs={}, mirostat=None, mirostat_eta=None, mirostat_tau=None, num_ctx=None, num_gpu=None, keep_alive=None, num_thread=None, repeat_last_n=None, repeat_penalty=None, temperature=None, stop=None, tfs_z=None, top_k=None, top_p=None)

# %%
embeddings.embed_query("Hello world")
# Out:
# [-0.0013338802,
#  0.005747513,
#  -0.010780195,
#  0.021867588,
#  0.025182243,
#  -0.004270991,
#  -0.012429548,
#  0.01415633,
#  0.019409988,
#  -0.023539187,
#  -0.0046492117,
#  -0.004619399,
#  -0.0051441435,
#  0.021350456,
#  -0.030207515,
#  -0.0031707452,
#  0.045325886,
#  -0.0044312705,
#  0.008987645,
#  -0.001239841,
#  0.008963616,
#  0.0124515835,
#  -0.01710249,
#  -0.013015654,
#  -0.027380947,
#  0.0055336463,
#  -0.014348643,
#  -0.0076980484,
#  0.025687171,
#  0.017795308,
#  0.009867087,
#  -0.00331709,
#  0.0070757656,
#  -0.0027233025,
#  -0.002528661,
#  0.007961669,
#  0.023003202,
#  -0.016140733,
#  0.011408171,
#  -0.0035245903,
#  0.015652869,
#  -0.017590256,
#  0.0042879125,
#  0.0009451694,
#  0.0041816127,
#  0.0025406557,
#  -0.011641614,
#  -0.003979132,
#  -0.03361386,
#  -0.022503361,
#  -0.25703073,
#  -0.29847664,
#  -0.015872234,
#  -0.0024188317,
#  -0.020303536,
#  0.0017728565,
#  -0.010892758,
#  0.0070569073,
#  -0.011417018,
# ...

# %% [markdown]
# ```markdown
# 2. Metni Vektöre Dönüştürme
# Amaç: "Hello world" metnini embedding vektörüne çevirmek.
# Ne yapıyor?: Girilen metni modelin embedding vektörüne dönüştürür.
# ```

# %% [markdown]
# ```markdown
# Genel Amaç
# Bu notebook'ta amaç, Ollama destekli bir embedding modeliyle metinleri vektörlere dönüştürmektir. Böylece metinler, arama, karşılaştırma veya LLM tabanlı uygulamalarda kullanılabilecek sayısal vektörlere çevrilmiş olur.
#
#
# ```
